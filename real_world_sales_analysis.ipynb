# %% [markdown]
# # Sales Analysis

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import os

# %%
files = list(os.listdir('./sales Data'))
print(*files, sep = '\n')
# Out:
# Sales_December_2019.csv
# Sales_April_2019.csv
# Sales_February_2019.csv
# Sales_March_2019.csv
# Sales_August_2019.csv
# Sales_May_2019.csv
# Sales_November_2019.csv
# Sales_October_2019.csv
# Sales_January_2019.csv
# Sales_September_2019.csv
# Sales_July_2019.csv
# Sales_June_2019.csv

# %% [markdown]
# as we have 12 months of separeted data, first we gonna merge all of those files into single dataset

# %%
# but before doing that, let's see what the data looks like
pd.read_csv('./sales Data/Sales_April_2019.csv')
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %% [markdown]
# so, this is how our data looks like. it has 6 columns including the time and date of purchase of a specific product.
# let's merge the data

# %%
all_df = pd.concat([pd.read_csv(f'./sales data/{file}') for file in files], ignore_index = True)
all_df
# Out:
#        Order ID                 Product Quantity Ordered Price Each  \
# 0        295665      Macbook Pro Laptop                1       1700
# 1        295666      LG Washing Machine                1      600.0
# 2        295667    USB-C Charging Cable                1      11.95
# 3        295668        27in FHD Monitor                1     149.99
# 4        295669    USB-C Charging Cable                1      11.95
# ...         ...                     ...              ...        ...
# 186845   222905  AAA Batteries (4-pack)                1       2.99
# 186846   222906        27in FHD Monitor                1     149.99
# 186847   222907    USB-C Charging Cable                1      11.95
# 186848   222908    USB-C Charging Cable                1      11.95
# 186849   222909  AAA Batteries (4-pack)                1       2.99
#
#             Order Date                        Purchase Address
# 0       12/30/19 00:01  136 Church St, New York City, NY 10001
# ...

# %% [markdown]
# Concatenation of all the data is done. let's save that complete data into a single file

# %%
all_df.to_csv('all_data.csv', index = False)

# %% [markdown]
# let's read the updated dataframe

# %%
data = pd.read_csv('all_data.csv')
data
# Out:
#        Order ID                 Product Quantity Ordered Price Each  \
# 0        295665      Macbook Pro Laptop                1       1700
# 1        295666      LG Washing Machine                1      600.0
# 2        295667    USB-C Charging Cable                1      11.95
# 3        295668        27in FHD Monitor                1     149.99
# 4        295669    USB-C Charging Cable                1      11.95
# ...         ...                     ...              ...        ...
# 186845   222905  AAA Batteries (4-pack)                1       2.99
# 186846   222906        27in FHD Monitor                1     149.99
# 186847   222907    USB-C Charging Cable                1      11.95
# 186848   222908    USB-C Charging Cable                1      11.95
# 186849   222909  AAA Batteries (4-pack)                1       2.99
#
#             Order Date                        Purchase Address
# 0       12/30/19 00:01  136 Church St, New York City, NY 10001
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %% [markdown]
# as we observe that, Dtype of every column is object. it means that the data present is either string or mixed type.
# for more information see [https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dtypes.html](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dtypes.html)

# %% [markdown]
# let's search for null values in the data

# %%
data.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %% [markdown]
# so we have 545 null values and we gonna drop'em all

# %%
data.dropna(inplace = True)
data.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %% [markdown]
# ## Data augmentation
# let's add month column to the data

# %%
data['month'] = data['Order Date'].str[:2].astype('int32')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 data['month'] = data['Order Date'].str[:2].astype('int32')
#
# File /opt/miniconda3/lib/python3.9/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File /opt/miniconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py:450, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %% [markdown]
# the reason why we're doing string slicing is that, the format of the date is **mm/dd/yyyy**. so if we grab the first 2 chars from that, we can get the job done

# %% [markdown]
# we have encountered an error. it says that it cannot convert string to int. the string is 'Or'.
# so, let's remove all the columns that has 'Or' in the month place of the order date.

# %%
data.loc[data['Order Date'].str[:2] == 'Or']
# Out:
#         Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 254     Order ID  Product  Quantity Ordered  Price Each  Order Date
# 705     Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1101    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2875    Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3708    Order ID  Product  Quantity Ordered  Price Each  Order Date
# ...          ...      ...               ...         ...         ...
# 183671  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 184012  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 184041  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 184275  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 186532  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#         Purchase Address
# 254     Purchase Address
# 705     Purchase Address
# 1101    Purchase Address
# 2875    Purchase Address
# ...

# %% [markdown]
# as we can see, some of the rows don't have proper date. instead they have string 'Order Date' as their data.

# %%
# or we can also do this instead to get the same result but in a different way
# let's try for searching for the most repeated value in Order Date column. so obviously it's gonna be 'Order Date'
data['Order Date'].value_counts()
# Out:
# Order Date        355
# 12/15/19 20:16      8
# 12/11/19 13:24      7
# 10/30/19 21:28      7
# 04/02/19 13:24      7
#                  ...
# 08/06/19 08:32      1
# 08/18/19 20:27      1
# 08/30/19 16:29      1
# 08/15/19 14:05      1
# 06/25/19 14:33      1
# Name: Order Date, Length: 142396, dtype: int64

# %% [markdown]
# so as we can see, Order Date value has repeated 355 times. so we can remove every row in the data which has Order Date in its Order Date Column

# %%
data.drop(data[data['Order Date'] == 'Order Date'].index, inplace = True)

# %%
data['Order Date'].value_counts()
# Out:
# 12/15/19 20:16    8
# 10/30/19 21:28    7
# 04/02/19 13:24    7
# 12/11/19 13:24    7
# 10/11/19 19:44    6
#                  ..
# 08/06/19 08:32    1
# 08/18/19 20:27    1
# 08/30/19 16:29    1
# 08/15/19 14:05    1
# 06/25/19 14:33    1
# Name: Order Date, Length: 142395, dtype: int64

# %% [markdown]
# now we don't have the Order Date value anymore in the dataset

# %%
# adding month column to the data
data['month'] = data['Order Date'].str[:2].astype('int32')
data
# Out:
#        Order ID                 Product Quantity Ordered Price Each  \
# 0        295665      Macbook Pro Laptop                1       1700
# 1        295666      LG Washing Machine                1      600.0
# 2        295667    USB-C Charging Cable                1      11.95
# 3        295668        27in FHD Monitor                1     149.99
# 4        295669    USB-C Charging Cable                1      11.95
# ...         ...                     ...              ...        ...
# 186845   222905  AAA Batteries (4-pack)                1       2.99
# 186846   222906        27in FHD Monitor                1     149.99
# 186847   222907    USB-C Charging Cable                1      11.95
# 186848   222908    USB-C Charging Cable                1      11.95
# 186849   222909  AAA Batteries (4-pack)                1       2.99
#
#             Order Date                        Purchase Address  month
# 0       12/30/19 00:01  136 Church St, New York City, NY 10001     12
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186849
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  object
#  3   Price Each        185950 non-null  object
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   month             185950 non-null  int32
# dtypes: int32(1), object(6)
# memory usage: 10.6+ MB

# %% [markdown]
# let's convert Quantity Ordered and Price Each column values to numbers (int and float)

# %%
data['Quantity Ordered'] = pd.to_numeric(data['Quantity Ordered'])
data['Price Each'] = pd.to_numeric(data['Price Each'])

# %% [markdown]
# ### adding sales column to the data
# qty * price = sales

# %%
data['Sales'] = data['Quantity Ordered'] * data['Price Each']
data.sort_values(by = 'Quantity Ordered', ascending = False)
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 163233   227096    AAA Batteries (4-pack)                 9        2.99
# 162597   226483    AAA Batteries (4-pack)                 9        2.99
# 174464   211097    AAA Batteries (4-pack)                 9        2.99
# 160735   224719    AAA Batteries (4-pack)                 8        2.99
# 112217   291034    AAA Batteries (4-pack)                 8        2.99
# ...         ...                       ...               ...         ...
# 65320    171357          Wired Headphones                 1       11.99
# 65321    171358  Lightning Charging Cable                 1       14.95
# 65322    171359  Lightning Charging Cable                 1       14.95
# 65323    171360           Vareebadd Phone                 1      400.00
# 186849   222909    AAA Batteries (4-pack)                 1        2.99
#
#             Order Date                        Purchase Address  month   Sales
# ...

# %% [markdown]
# ## adding city column

# %%
def get_city(address):
    return f'{address.split(",")[1].strip()} ({address.split(",")[2].split(" ")[1]})'

data['City'] = data['Purchase Address'].apply(get_city)
data
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 0        295665      Macbook Pro Laptop                 1     1700.00
# 1        295666      LG Washing Machine                 1      600.00
# 2        295667    USB-C Charging Cable                 1       11.95
# 3        295668        27in FHD Monitor                 1      149.99
# 4        295669    USB-C Charging Cable                 1       11.95
# ...         ...                     ...               ...         ...
# 186845   222905  AAA Batteries (4-pack)                 1        2.99
# 186846   222906        27in FHD Monitor                 1      149.99
# 186847   222907    USB-C Charging Cable                 1       11.95
# 186848   222908    USB-C Charging Cable                 1       11.95
# 186849   222909  AAA Batteries (4-pack)                 1        2.99
#
#             Order Date                        Purchase Address  month  \
# ...

# %%
data['City'].value_counts()
# Out:
# San Francisco (CA)    44732
# Los Angeles (CA)      29605
# New York City (NY)    24876
# Boston (MA)           19934
# Atlanta (GA)          14881
# Dallas (TX)           14820
# Seattle (WA)          14732
# Portland (OR)         10010
# Austin (TX)            9905
# Portland (ME)          2455
# Name: City, dtype: int64

# %% [markdown]
# ## Question 1: What's the best month in terms of sales?

# %%
month_wise_sales = data.groupby('month').sum(numeric_only=True)
month_wise_sales
# Out:
#        Quantity Ordered  Price Each       Sales
# month
# 1                 10903  1811768.38  1822256.73
# 2                 13449  2188884.72  2202022.42
# 3                 17005  2791207.83  2807100.38
# 4                 20558  3367671.02  3390670.24
# 5                 18667  3135125.13  3152606.75
# 6                 15253  2562025.61  2577802.26
# 7                 16072  2632539.56  2647775.76
# 8                 13448  2230345.42  2244467.88
# 9                 13109  2084992.09  2097560.13
# 10                22703  3715554.83  3736726.88
# 11                19798  3180600.68  3199603.20
# 12                28114  4588415.41  4613443.34

# %%
import seaborn as sb
import matplotlib.pyplot as plt
sb.set()
figure, axis = plt.subplots(1, 2, figsize = (15, 5))
sb.lineplot(x = month_wise_sales.index,
            y = month_wise_sales['Sales'], 
            ax = axis[0], 
            color = 'red', 
            marker = 'o')
axis[0].set_title('Sales Trend')
axis[0].set_ylabel('Sales in USD')
axis[0].ticklabel_format(style = 'plain', axis = 'y')
sb.barplot(x = month_wise_sales.index, y = month_wise_sales['Sales'], ax = axis[1], )
axis[1].set_title('Monthly Sales')
axis[1].set_ylabel('Sales in USD')
axis[1].ticklabel_format(style = 'plain', axis = 'y')

# %% [markdown]
# ## Question 2: Which city has more number of sales?

# %%
city_wise_sales = data.groupby('City').sum(numeric_only=True)
city_wise_sales = city_wise_sales.drop(['month', 'Price Each'], axis = 1)
city_wise_sales
# Out:
#                     Quantity Ordered       Sales
# City
# Atlanta (GA)                   16602  2795498.58
# Austin (TX)                    11153  1819581.75
# Boston (MA)                    22528  3661642.01
# Dallas (TX)                    16730  2767975.40
# Los Angeles (CA)               33289  5452570.80
# New York City (NY)             27932  4664317.43
# Portland (ME)                   2750   449758.27
# Portland (OR)                  11303  1870732.34
# San Francisco (CA)             50239  8262203.91
# Seattle (WA)                   16553  2747755.48

# %%
data['City'].value_counts().plot(kind = 'bar', color = 'red', title='Value Counts of Cities')
# Out:
# <AxesSubplot: title={'center': 'Value Counts of Cities'}>

# %%
sb.barplot(x=city_wise_sales.index, y=city_wise_sales['Sales'])
plt.ticklabel_format(style = 'plain', axis = 'y')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## Question 3: What's the best time to advertise to maximise the sales?

# %%
data
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 0        295665      Macbook Pro Laptop                 1     1700.00
# 1        295666      LG Washing Machine                 1      600.00
# 2        295667    USB-C Charging Cable                 1       11.95
# 3        295668        27in FHD Monitor                 1      149.99
# 4        295669    USB-C Charging Cable                 1       11.95
# ...         ...                     ...               ...         ...
# 186845   222905  AAA Batteries (4-pack)                 1        2.99
# 186846   222906        27in FHD Monitor                 1      149.99
# 186847   222907    USB-C Charging Cable                 1       11.95
# 186848   222908    USB-C Charging Cable                 1       11.95
# 186849   222909  AAA Batteries (4-pack)                 1        2.99
#
#             Order Date                        Purchase Address  month  \
# ...

# %% [markdown]
# - let's add a hour column to see at what hour purchase has been made

# %%
data['hour'] = pd.to_datetime(data['Order Date']).dt.hour
data
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 0        295665      Macbook Pro Laptop                 1     1700.00
# 1        295666      LG Washing Machine                 1      600.00
# 2        295667    USB-C Charging Cable                 1       11.95
# 3        295668        27in FHD Monitor                 1      149.99
# 4        295669    USB-C Charging Cable                 1       11.95
# ...         ...                     ...               ...         ...
# 186845   222905  AAA Batteries (4-pack)                 1        2.99
# 186846   222906        27in FHD Monitor                 1      149.99
# 186847   222907    USB-C Charging Cable                 1       11.95
# 186848   222908    USB-C Charging Cable                 1       11.95
# 186849   222909  AAA Batteries (4-pack)                 1        2.99
#
#             Order Date                        Purchase Address  month  \
# ...

# %%
data['hour'].value_counts().plot(kind = 'bar', color = 'red', title='Value Counts of Hours')
# Out:
# <AxesSubplot: title={'center': 'Value Counts of Hours'}>

# %%
sb.lineplot(x = data['hour'].value_counts().index, y = data['hour'].value_counts(), color = 'red', marker = 'o')
plt.xticks(data['hour'].value_counts().index)
plt.xlabel('Hours')
plt.ylabel('Number of Orders')
plt.show()

# %% [markdown]
# so we can see the trend that, after 10AM the sales when high till 1 PM and again peaked at 5 to 7 PM

# %% [markdown]
# ## Question 4: What products are most often sold together?

# %% [markdown]
# if we look at the data, if a person makes a purchase, for all the prodcuts, the order ID would be same.

# %%
data['Order ID'].value_counts()
# Out:
# 160873    5
# 196615    4
# 277875    4
# 263918    4
# 194253    4
#          ..
# 169618    1
# 169619    1
# 169620    1
# 169621    1
# 222909    1
# Name: Order ID, Length: 178437, dtype: int64

# %%
data.loc[data['Order ID'] == '160873']
# Out:
#       Order ID                   Product  Quantity Ordered  Price Each  \
# 54336   160873                    iPhone                 1      700.00
# 54337   160873  Lightning Charging Cable                 1       14.95
# 54338   160873  Apple Airpods Headphones                 1      150.00
# 54339   160873          Wired Headphones                 1       11.99
# 54340   160873              Google Phone                 1      600.00
#
#            Order Date                       Purchase Address  month   Sales  \
# 54336  02/10/19 10:24  702 River St, San Francisco, CA 94016      2  700.00
# 54337  02/10/19 10:24  702 River St, San Francisco, CA 94016      2   14.95
# 54338  02/10/19 10:24  702 River St, San Francisco, CA 94016      2  150.00
# 54339  02/10/19 10:24  702 River St, San Francisco, CA 94016      2   11.99
# 54340  02/10/19 10:24  702 River St, San Francisco, CA 94016      2  600.00
#
#                      City  hour
# 54336  San Francisco (CA)    10
# ...

# %%
data['Order ID'].value_counts()
# Out:
# 160873    5
# 196615    4
# 277875    4
# 263918    4
# 194253    4
#          ..
# 169618    1
# 169619    1
# 169620    1
# 169621    1
# 222909    1
# Name: Order ID, Length: 178437, dtype: int64

# %%
order_id_data = {'Order ID': data['Order ID'].value_counts().index, 'Count': data['Order ID'].value_counts().values}
order_id_data = pd.DataFrame(order_id_data)
order_id_data = order_id_data[order_id_data['Count'] > 1]
order_id_data
# Out:
#      Order ID  Count
# 0      160873      5
# 1      196615      4
# 2      277875      4
# 3      263918      4
# 4      194253      4
# ...       ...    ...
# 7131   160538      2
# 7132   222882      2
# 7133   155031      2
# 7134   205923      2
# 7135   217666      2
#
# [7136 rows x 2 columns]

# %% [markdown]
# so we have 7136 orders that have multiple purchases on the same order ID

# %%
data.loc[data['Order ID'] == '160873']['Product'].to_list()
# Out:
# ['iPhone',
#  'Lightning Charging Cable',
#  'Apple Airpods Headphones',
#  'Wired Headphones',
#  'Google Phone']

# %%
order_ids = order_id_data['Order ID'].to_list()
order_id_procucts = {order_id: data.loc[data['Order ID'] == order_id]['Product'].to_list() for order_id in order_ids}

# %%
order_id_data['Products'] = order_id_data['Order ID'].map(order_id_procucts)

# %%
pd.set_option('display.max_colwidth', None)
order_id_data
# Out:
#      Order ID  Count  \
# 0      160873      5
# 1      196615      4
# 2      277875      4
# 3      263918      4
# 4      194253      4
# ...       ...    ...
# 7131   160538      2
# 7132   222882      2
# 7133   155031      2
# 7134   205923      2
# 7135   217666      2
#
#                                                                                           Products
# 0     [iPhone, Lightning Charging Cable, Apple Airpods Headphones, Wired Headphones, Google Phone]
# 1               [Google Phone, USB-C Charging Cable, Bose SoundSport Headphones, Wired Headphones]
# 2                                   [Google Phone, USB-C Charging Cable, Wired Headphones, iPhone]
# 3            [Vareebadd Phone, USB-C Charging Cable, Bose SoundSport Headphones, Wired Headphones]
# 4                       [iPhone, Lightning Charging Cable, Wired Headphones, USB-C Charging Cable]
# ...                                                                                            ...
# ...

# %%
from itertools import combinations
from collections import Counter

count = Counter()

for row in order_id_data['Products']:
    count.update(Counter(combinations(row, 2)))

count.most_common(10)
# Out:
# [(('iPhone', 'Lightning Charging Cable'), 1005),
#  (('Google Phone', 'USB-C Charging Cable'), 987),
#  (('iPhone', 'Wired Headphones'), 447),
#  (('Google Phone', 'Wired Headphones'), 414),
#  (('Vareebadd Phone', 'USB-C Charging Cable'), 361),
#  (('iPhone', 'Apple Airpods Headphones'), 360),
#  (('Google Phone', 'Bose SoundSport Headphones'), 220),
#  (('USB-C Charging Cable', 'Wired Headphones'), 160),
#  (('Vareebadd Phone', 'Wired Headphones'), 143),
#  (('Lightning Charging Cable', 'Wired Headphones'), 92)]

# %% [markdown]
# these are the most commonly sold items together

# %% [markdown]
# ## Question 5: Most sold Product? and why?

# %%
data['Product'].value_counts()
# Out:
# USB-C Charging Cable          21903
# Lightning Charging Cable      21658
# AAA Batteries (4-pack)        20641
# AA Batteries (4-pack)         20577
# Wired Headphones              18882
# Apple Airpods Headphones      15549
# Bose SoundSport Headphones    13325
# 27in FHD Monitor               7507
# iPhone                         6842
# 27in 4K Gaming Monitor         6230
# 34in Ultrawide Monitor         6181
# Google Phone                   5525
# Flatscreen TV                  4800
# Macbook Pro Laptop             4724
# ThinkPad Laptop                4128
# 20in Monitor                   4101
# Vareebadd Phone                2065
# LG Washing Machine              666
# LG Dryer                        646
# Name: Product, dtype: int64

# %% [markdown]
# Note: value_counts() returns the numbre of times a value has appeared in the dataframe. if a person buys 2 products, it still counts as one product when we use value_counts() function.

# %% [markdown]
# if a product is affordable and has important usecases, the likelyness of the product to be sold is more. so let's see the price of the each product and we can come to a conclusion of why that product is sold more..

# %%
data
# Out:
#        Order ID                 Product  Quantity Ordered  Price Each  \
# 0        295665      Macbook Pro Laptop                 1     1700.00
# 1        295666      LG Washing Machine                 1      600.00
# 2        295667    USB-C Charging Cable                 1       11.95
# 3        295668        27in FHD Monitor                 1      149.99
# 4        295669    USB-C Charging Cable                 1       11.95
# ...         ...                     ...               ...         ...
# 186845   222905  AAA Batteries (4-pack)                 1        2.99
# 186846   222906        27in FHD Monitor                 1      149.99
# 186847   222907    USB-C Charging Cable                 1       11.95
# 186848   222908    USB-C Charging Cable                 1       11.95
# 186849   222909  AAA Batteries (4-pack)                 1        2.99
#
#             Order Date                        Purchase Address  month  \
# ...

# %%
products_sold = data.groupby('Product').sum(numeric_only=True)['Quantity Ordered']

# %%
products_sold
# Out:
# Product
# 20in Monitor                   4129
# 27in 4K Gaming Monitor         6244
# 27in FHD Monitor               7550
# 34in Ultrawide Monitor         6199
# AA Batteries (4-pack)         27635
# AAA Batteries (4-pack)        31017
# Apple Airpods Headphones      15661
# Bose SoundSport Headphones    13457
# Flatscreen TV                  4819
# Google Phone                   5532
# LG Dryer                        646
# LG Washing Machine              666
# Lightning Charging Cable      23217
# Macbook Pro Laptop             4728
# ThinkPad Laptop                4130
# USB-C Charging Cable          23975
# Vareebadd Phone                2068
# Wired Headphones              20557
# iPhone                         6849
# Name: Quantity Ordered, dtype: int64

# %%
sb.barplot(x = products_sold.index, y = products_sold.values)
plt.xticks(rotation = 90)
plt.show()

# %%
price_of_each_product = data.groupby('Product').mean(numeric_only=True)['Price Each']
price_of_each_product
# Out:
# Product
# 20in Monitor                   109.99
# 27in 4K Gaming Monitor         389.99
# 27in FHD Monitor               149.99
# 34in Ultrawide Monitor         379.99
# AA Batteries (4-pack)            3.84
# AAA Batteries (4-pack)           2.99
# Apple Airpods Headphones       150.00
# Bose SoundSport Headphones      99.99
# Flatscreen TV                  300.00
# Google Phone                   600.00
# LG Dryer                       600.00
# LG Washing Machine             600.00
# Lightning Charging Cable        14.95
# Macbook Pro Laptop            1700.00
# ThinkPad Laptop                999.99
# USB-C Charging Cable            11.95
# Vareebadd Phone                400.00
# Wired Headphones                11.99
# iPhone                         700.00
# Name: Price Each, dtype: float64

# %%
g = sb.lineplot(x = price_of_each_product.index, y = price_of_each_product.values)
plt.xticks(rotation = 90)
plt.ylabel('Price in USD')
plt.show()

# %%
alldata = {'Product': products_sold.index, 
           'Quantity Ordered': products_sold.values,
           'Price Each': price_of_each_product.values}

alldata = pd.DataFrame(alldata, columns = ['Product', 'Quantity Ordered', 'Price Each'])
alldata
# Out:
#                        Product  Quantity Ordered  Price Each
# 0                 20in Monitor              4129      109.99
# 1       27in 4K Gaming Monitor              6244      389.99
# 2             27in FHD Monitor              7550      149.99
# 3       34in Ultrawide Monitor              6199      379.99
# 4        AA Batteries (4-pack)             27635        3.84
# 5       AAA Batteries (4-pack)             31017        2.99
# 6     Apple Airpods Headphones             15661      150.00
# 7   Bose SoundSport Headphones             13457       99.99
# 8                Flatscreen TV              4819      300.00
# 9                 Google Phone              5532      600.00
# 10                    LG Dryer               646      600.00
# 11          LG Washing Machine               666      600.00
# 12    Lightning Charging Cable             23217       14.95
# 13          Macbook Pro Laptop              4728     1700.00
# ...

# %%
ax = alldata.plot(kind = 'bar', x = 'Product',
                  y = 'Quantity Ordered', color='green', figsize = (10, 10))
 
ax2 = alldata.plot(kind = 'line', x = 'Product',
                   y = 'Price Each', secondary_y = True,ax = ax, linewidth = 2, color='red')
 
#title of the plot
plt.title("total sales vs price of each product")
 
#labeling x and y-axis
ax.set_xlabel('Product', color = 'green')
ax.set_ylabel('total sales', color = "green")
ax.set_xticklabels(alldata['Product'], rotation = 90)
ax2.set_ylabel('Price each', color = 'red')
 
#defining display layout
plt.tight_layout()
#show plot
plt.show()

# %% [markdown]
# so when the product is cheap, the sales are high and in another case, when it comes to electronis, even though the price is high, the sales are considerably more. so it all comes to use case and price as well.
# - if we look at LG Dryer, the sales are pretty low as the price is more
